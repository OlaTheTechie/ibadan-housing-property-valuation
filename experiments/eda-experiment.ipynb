# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ibadan_synthetic_housing.csv")
df.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  2660         6          1        3       no        no       no
# 1  1298         3          3        2      yes        no       no
# 2  2842         3          3        1      yes        no       no
# 3  3050         3          1        2      yes        no       no
# 4  3004         4          1        2       no        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no              no        1       no      unfurnished
# 1              no              no        0      yes   semi-furnished
# 2              no              no        2       no      unfurnished
# 3              no             yes        0       no        furnished
# 4              no              no        0       no   semi-furnished
#
#          location  desirability_score  loc_multiplier  price_usd  price_naira  \
# ...

# %%
df = df.drop(columns=["price_usd", "loc_multiplier"])

# %%
num_features = df.select_dtypes("number").columns.tolist()
cat_features = df.select_dtypes("object").columns.tolist()

num_features, cat_features
# Out:
# (['area',
#   'bedrooms',
#   'bathrooms',
#   'stories',
#   'parking',
#   'desirability_score',
#   'loc_multiplier',
#   'price_usd',
#   'price_naira',
#   'latitude',
#   'longitude',
#   'price_per_sqft_naira'],
#  ['mainroad',
#   'guestroom',
#   'basement',
#   'hotwaterheating',
#   'airconditioning',
#   'prefarea',
#   'furnishingstatus',
#   'location'])

# %%
df[num_features].corr()["price_naira"].abs().plot(kind="barh")
# Out:
# <Axes: >
